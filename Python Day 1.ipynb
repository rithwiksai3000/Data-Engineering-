# %%
print("Hello Joeyyyy!")
# Out:
# Hello Joeyyyy!

# %% [raw]
# # Data Types
# # Intergers

# %%
a=9
b=3
c=a+b
print(c)
print(a+b)
# Out:
# 12
# 12

# %%
a=7
print("fghhjj" + a)

## Cannot concatenate string and integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a=7
# ----> 2 print("fghhjj" + a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Now we conver the value in a to a string using str() 

a =7

print("sddfg" + str(a))
# Out:
# sddfg7

# %%
# Float : Decimals
x=1.345
x
# Out:
# 1.345

# %%
# Boolean

# %%
# Strings

# %%
# Complex
j = 1.0 - 2.0j
j
type(j)
# Out:
# complex

# %%
print(j.real , j.imag)
# Out:
# 1.0 -2.0

# %% [raw]
# Defining Variables

# %%
# In heap memory , 10 value is assigned first , then again 15 is reassigned to the variable

tenth = 10

tenth=15
tenth
# Out:
# 15

# %% [raw]
# Dynamic Typing
#
# The variable by itself doesnt have a datatype , it takes the datatype of the value assigned to it

# %%
ten = 10
type(ten)
# Out:
# int

# %%
print("str" + str(1))
# Out:
# str1

# %% [raw]
# Operators in Python

# %%
a=10
b=4
print( a + b )
print( a - b )
print( a * b )
print( a / b )
print( a % b)
print( a ** b )
print(  a // b)
# Out:
# 14
# 6
# 40
# 2.5
# 2
# 10000
# 2

# %% [raw]
# Comparision Operators

# %%
a=5
b=7
print(  a==b )
print( a!=b  )
print(  a<b )
print(  a>b )
print(   a<=b)
print(  a>=b )
# Out:
# False
# True
# True
# False
# True
# False

# %% [raw]
# Logical Operators

# %%
x = True
y= False
print( x and y  )
print(  x or y )
print( not y  )
# Out:
# False
# True
# True

# %% [raw]
# Assignment Operators

# %%
x=5
x=+5
x=-5
x


x+=5
x
# Out:
# 0

# %%
# Input Function
name= str(input("Enter your name: "))
print("Hello" , name)
print(type(name))
# Out:
# Enter your name:  1
# Hello 1
# <class 'str'>

# %%
# f string
age= 48
type(age)
year= 1978
x= f"I am {age} yrs old, born in {year}"
print(x)
# Out:
# I am 48 yrs old, born in 1978

# %%
language = "Python"
subject = 'fghj'
print("I love {} , my subject is {}".format(language, subject))
# Out:
# I love Python , my subject is fghj

# %% [raw]
# Branching (if/elif/else)

# %%
i =6
if(i<3):
    print('less than 3')
    if i<2:
        print("FGHHJ")
elif i<5:
    print('less than 5')
elif i<12:
    print("He is stupid")
else:
    print('5 or more')
# Out:
# He is stupid
