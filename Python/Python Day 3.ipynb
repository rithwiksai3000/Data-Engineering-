# %% [raw]
# Strings and List Objects

# %%
# Creating Strings
# single or double quotes

# %%
'hello'
"String with double quotes"

# %%
'hello'
# Can print strings without print stmt
# Out:
# 'hello'

# %%
'hello'
'hello1'
# Will print only the latest written string
# Out:
# 'hello1'

# %%
# \n to print in a new line
print('Hello world')
print('\n')
'Hello World'
# Out:
# Hello world
# 'Hello World'

# %%
len('hello world')
# space also considered as a char so we have +1 in length
# Out:
# 11

# %%
# Indexing
s="Hey man , youre gay !"

# %%
print(s)
# Out:
# Hey man , youre gay !

# %%
s[0]
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
s[-1]
# Out:
# '!'

# %%
s
# Out:
# 'Hey man , youre gay !'

# %%
# Slicing

# %%
s[0:]
# Out:
# 'Hey man , youre gay !'

# %%
s[:5]
# Out:
# 'Hey m'

# %%
s[:]
# Out:
# 'Hey man , youre gay !'

# %%
s[:-1]
# Out:
# 'Hey man , youre gay '

# %%
s[0:10:2]
# Out:
# 'Hymn,'

# %%
s[::3]
# grab everything , but go in step size of 1
# Out:
# 'H n u y'

# %%
s[::-1]
# print the string in reverse order
# Out:
# '! yag eruoy , nam yeH'

# %%
s[::2]
# grab everything in step size of 2
# Out:
# 'Hymn,yuegy!'

# %% [raw]
# Strings are Immutable , if we create a string with specific value , we cant change the data or reassign to another data

# %%
s='Hello'

# %%
l = 'zHJopq'
l
# Out:
# 'zHJopq'

# %%
letter *50
# Out:
# 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz'

# %% [raw]
# Built in String Functions

# %%
l.upper()
# Out:
# 'ZHJOPQ'

# %%
l.lower()
# Out:
# 'zhjopq'

# %%
l.split('j')
# Out:
# ['zHJopq']

# %%
l.count('z')
# Out:
# 1

# %%
l.find('z')
# Out:
# 0

# %% [raw]
# is check methods

# %%
s='hello'

# %%
s.isalnum()
#
# Out:
# True

# %%
x='Hritvik'
x.isalpha()
# checks for aplha numeric or not
# Out:
# True

# %%
j='Hritv'
j.islower()
# Out:
# False

# %%
j.isspace()
# returns true if all are white space chars
# Out:
# False

# %%
p='Hritv'
p.istitle()
# if the string starts with Capital letter
# Out:
# True

# %% [raw]
# Built in Reg Expressions

# %%
s='hello4'
s.endswith('o')
# Out:
# False

# %%
s.split('e')
# Out:
# ['h', 'llo4']

# %%
l='hellooepp'
l.partition('e')
# Out:
# ('h', 'e', 'llooepp')

# %%
s
# Out:
# 'hello4'

# %% [raw]
# Lists
# -> They are mutable
# -> Can add mutiple entries of different data types

# %%
mylist=['one' , 'two' , 'three' , 4,5]
mylist
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
mylist[2]
# Out:
# 'three'

# %%
mylist[1:]
# Out:
# ['two', 'three', 4, 5]

# %%
mylist[:5:2]
# Out:
# ['one', 'three', 5]

# %%
# use + to add or ooncat into the list
# appends at the end
mylist= mylist +[5,7]
mylist
# Out:
# ['one', 'two', 'three', 4, 5, 5, 7]

# %%
mylist.pop(5)
mylist
# Out:
# ['one', 'two', 'three', 4, 5, 7]

# %%
mylist.reverse()
mylist
# Out:
# [7, 5, 4, 'three', 'two', 'one']

# %%
o=[1,4,7,6,3,2]
o.sort()
o
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
l1=[1,2,3]
l2=[4,5,6]
l3=[7,8,9]

matrix=[l1,l2,l3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[2]
# Out:
# [7, 8, 9]

# %%
matrix[0][0]
# Out:
# 1

# %%
matrix[0][1]
# Out:
# 2

# %%
matrix[1][0]
# Out:
# 4

# %% [raw]
# List Comprehensions

# %%
fcol= [row[0] for row in matrix]
fcol
# Out:
# [1, 4, 7]

# %%
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
l.append(6)
l
# Out:
# [1, 2, 3, 4, 6, 6]

# %%
l.count(6)
# Out:
# 2
