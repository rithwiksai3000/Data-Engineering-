# %% [raw]
# Modules and Libraries

# %%
import pandas as pd

# %% [raw]
# Module: These are the files that have functions
# Libraries: We have functions and methods to use , defined and created in the module

# %% [raw]
# Errors and Exception Handling

# %%
try:
    printf('Hello')
except:
    print('syntax Error')
# Out:
# syntax Error

# %%
import pandas as pd
data={
    "Name": ['Alice' , 'Bob' , 'Charlie'],
    "Marks" : [85,90,98,]
}
df=pd.DataFrame(data)
df
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     98

# %%
df.to_excel("filename" , index=false)

or 

df.to_csv("filename" , index=false)

# %% [raw]
# Database connectivity

# %%
import sqlite3

# %%
db=sqlite3.connect("my_database.db)

# %%
default sytntax: db.execute
